# %%
# Editing
s="Hello"
s[0]="X"  #give error becouse string are immutable
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Editing
#       2 s="Hello"
# ----> 3 s[0]="X"
#       4 print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
s="Ram"
print(s)
# Out:
# Ram

# %%
s[3]="t" #you can not add character also

# %%
# Delete

# %%
del s #here s is delete

# %%
print(s) #give error - becouse s are alrady delete and does not exist now
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(s)
#
# NameError: name 's' is not defined

# %%
s="Hello"
print(s)
# Out:
# Hello

# %%
del s[0] # give error becouse we cannot delete a particular char - string are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 del s[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
del(s[:3:2]) #give error - string are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 del(s[:3:2])
#
# TypeError: 'str' object does not support item deletion
