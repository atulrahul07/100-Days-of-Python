# %%
# math module / library
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(6)
# Out:
# 720

# %%
math.gcd(3,7)
# Out:
# 1

# %%
math.ceil(6.9)
# Out:
# 7

# %%
math.floor(6.9)
# Out:
# 6

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
# random module
import random

# %%
random.randint(1,100)
# Out:
# 42

# %%
a=[1,2,3,4,5]
random.shuffle(a)
print(a)
# Out:
# [3, 5, 2, 4, 1]

# %%
# time module
import time

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=4, tm_mday=28, tm_hour=16, tm_min=3, tm_sec=25, tm_wday=1, tm_yday=118, tm_isdst=0)

# %%
time.time()
# Out:
# 1777372444.004

# %%
time.ctime()
# Out:
# 'Tue Apr 28 16:04:34 2026'

# %%
print("Hello")
time.sleep(2)
print("World")
# Out:
# Hello
# World

# %%
# os module
import os

# %%
os.getcwd()
# Out:
# '/drive'

# %%
os.listdir()
# Out:
# ['100 days of python',
#  'day-16-break-continue-pass.ipynb',
#  'day_09_operators.ipynb',
#  'day_10_if-else.ipynb',
#  'day_11_indentation.ipynb',
#  'day_12_while-loop.ipynb',
#  'day_13_guessing-game.ipynb',
#  'day_14_for-loop.ipynb',
#  'day_15_nested-loop.ipynb',
#  'day_17_built-in-function.ipynb',
#  'day_18_build-in-modules.ipynb',
#  'lec_01_print.ipynb',
#  'lec_02_dataTypes.ipynb',
#  'lec_03_comments.ipynb',
#  'lec_04_variables.ipynb',
#  'lec_05_keywords_and_identifiers.ipynb',
#  'lec_06_input.ipynb',
#  'lec_07_type_conversion.ipynb',
#  'lec_08_literals.ipynb',
#  'README.md',
#  'data',
#  'notebooks']
