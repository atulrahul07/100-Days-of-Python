# %%
#interger
print(5)
print(1e307)
# Out:
# 5
# 1e+307

# %%
#float
print(3.6)
# Out:
# 3.6

# %%
#boolean
print(False,True)
# Out:
# False True

# %%
#complex - complex number
print(4+4j)
# Out:
# (4+4j)

# %%
#string
print('ATUL')
print("ATUL")
print("""ATUL""")
# Out:
# ATUL
# ATUL
# ATUL

# %%
#list
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
#tuple
print((1,2,3,4))
# Out:
# (1, 2, 3, 4)

# %%
#set
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
#dics
print({"Name":"Nitish", "Age":30, "Gender":"Male"})
# Out:
# {'Name': 'Nitish', 'Age': 30, 'Gender': 'Male'}
