# %%
name=input("Enter your name : ")
# Out:
# Enter your name :  Atul Kumar Pal

# %%
print(name)
# Out:
# Atul Kumar Pal

# %%
first_num=input("Enter first number")
second_num=input("Enter second number")
print(first_num+second_num)
# Out:
# Enter first number 56
# Enter second number 76
# 5676

# %%
#type
type(4)
# Out:
# int

# %%
type(4.5)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type("Name")
# Out:
# str

# %%
type(6+7j)
# Out:
# complex
