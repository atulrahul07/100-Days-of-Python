# %%
#sets
#sets do not allow duplicates
#sets have no indexing
#sets do not allow mutuable data types
#sets itself is a mutuable data types

# %%
#creating a set

# %%
#for creating a empty set
s1=set()
type(s1)
# Out:
# set

# %%
s1={1,2,3,4,5}

# %%
s2={"hello",1,5.4,True}
print(s2)
# Out:
# {5.4, 1, 'hello'}

# %%
s3={1,2,1,2}
print(s3)
# Out:
# {1, 2}

# %%
s4={[1,2],"Hello"} #give error becouse list is mutuable data type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s4={[1,2],"Hello"} #give error becouse list is mutuable data type
#
# TypeError: unhashable type: 'list'

# %%
s4={(1,2),"Hello"}
print(s4)
# Out:
# {(1, 2), 'Hello'}

# %%
#acces item in sets

# %%
s1={1,2,3,4,5}
print(s1[0]) #give error becouse sets do not have indexing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 s1={1,2,3,4,5}
# ----> 2 print(s1[0])
#
# TypeError: 'set' object is not subscriptable

# %%
#we can not edit sets

# %%
# add item in set

# %%
id(s1)
# Out:
# 63006232

# %%
s1.add(6)
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
id(s1)
# Out:
# 63006232

# %%
#delete 
#del
#remove
#pop

# %%
del s2 #it will delete entire set

# %%
s1.remove(5)
print(s1)
# Out:
# {1, 2, 3, 4, 6}

# %%
s1.pop()
print(s1)
# Out:
# {2, 3, 4, 6}

# %%
#set operations

# %%
s1={1,2,3,4}
s2={3,2,5,6}

# %%
for i in s1:
    print(i)
# Out:
# 2
# 3
# 4
# 6

# %%
1 in s1
# Out:
# True

# %%
#function

# %%
len(s1)
# Out:
# 4

# %%
min(s1)
# Out:
# 2

# %%
max(s2)
# Out:
# 6

# %%
sum(s1)
# Out:
# 10

# %%
sorted(s1)
# Out:
# [1, 2, 3, 4]

# %%
s1={1,2,3,4}
s2={3,2,5,6}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {2, 3}

# %%
s1.difference(s2)
# Out:
# {1, 4}

# %%
s2.difference(s1)
# Out:
# {5, 6}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 4, 5, 6}

# %%
s1.isdisjoint(s2) #return true when intersection of both the set is null
# Out:
# False

# %%
s1.issubset(s2) #return true when all the item of s1 is present in s2
# Out:
# False

# %%
s1.issuperset(s2) #return true when all the item of s2 is present in s1
# Out:
# False

# %%
s1.clear(
