# %%
#dictionary has no indexing
#dictionary is mutuable data types
#keys->immutable    value->they can be mutuable
#keys should be unique

# %%
#create

# %%
d={}
type(d)
# Out:
# dict

# %%
d={"Name":"Atul","Gender":"Male"}
print(d1)
# Out:
# {'Name': 'Atul', 'Gender': 'Male'}

# %%
d1={[1,2,3]:"Atul"} #keys must be immutable data types
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 d1={[1,2,3]:"Atul"}
#
# TypeError: unhashable type: 'list'

# %%
d1={(1,2,3):"Atul"}

# %%
d2={"Name":"Rahul", "Name":"Atul"}
print(d2)  #keys must be unique
# Out:
# {'Name': 'Atul'}

# %%
#2d dictionary

# %%
d2={"Name":"Atul", "College":"NSUT","Marks":{"OS":90, "DS":89, "OOPS":99,"DSA":85}}
print(d2)
# Out:
# {'Name': 'Atul', 'College': 'NSUT', 'Marks': {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 85}}

# %%
# Accessing item from dictionary

# %%
d2["Name"]
# Out:
# 'Atul'

# %%
d2["Marks"]
# Out:
# {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 85}

# %%
d2["Marks"]["DSA"]
# Out:
# 85

# %%
# Edit item in dictionary

# %%
d2["Name"]="Rahul"
print(d2)
# Out:
# {'Name': 'Rahul', 'College': 'NSUT', 'Marks': {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 85}}

# %%
d2["Marks"]["DSA"]=100
print(d2)
# Out:
# {'Name': 'Rahul', 'College': 'NSUT', 'Marks': {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 100}}

# %%
# Access using get function

# %%
d2.get("Name")
# Out:
# 'Rahul'

# %%
d2.get("Marks")
# Out:
# {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 100}

# %%
# adding new key-value pair in dictionary

# %%
d2["Gender"]="Male"
print(d2)
# Out:
# {'Name': 'Rahul', 'College': 'NSUT', 'Marks': {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 100}, 'Gender': 'Male'}

# %%
d2["Marks"]["AIML"]=80
print(d2)
# Out:
# {'Name': 'Rahul', 'College': 'NSUT', 'Marks': {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 100, 'AIML': 80}, 'Gender': 'Male'}

# %%
# delete

# %%
d5={}
print(d5)
# Out:
# {}

# %%
del d5

# %%
del d2["Gender"]
print(d2)
# Out:
# {'Name': 'Rahul', 'College': 'NSUT', 'Marks': {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 100, 'AIML': 80}}

# %%
d1.clear() #dict become empty
print(d1)
# Out:
# {}

# %%
#operations

# %%
for i in d2: 
    print(i) #it will only print keys of dictionary
# Out:
# Name
# College
# Marks

# %%
for i in d2:
    print(i,d2[i]) # if you want key and value both then use like this
# Out:
# Name Rahul
# College NSUT
# Marks {'OS': 90, 'DS': 89, 'OOPS': 99, 'DSA': 100, 'AIML': 80}

# %%
"Name" in d2
# Out:
# True

# %%
"Rahul" in d2
# Out:
# False

# %%
len(d2)
# Out:
# 3

# %%
min(d2)
# Out:
# 'College'

# %%
max(d2)
# Out:
# 'Name'

# %%
sorted(d2)
# Out:
# ['College', 'Marks', 'Name']

# %%
sorted(d2,reverse=True)
# Out:
# ['Name', 'Marks', 'College']

# %%
d3.
