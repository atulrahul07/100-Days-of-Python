# %%
#while-loop
while condition:
    code to be executed

# %%
number=int(input("Enter a number"))
i=1
while i<=10:
    print(number,"*",i,"=",number*i)
    i+=1
# Out:
# Enter a number 89
# 89 * 1 = 89
# 89 * 2 = 178
# 89 * 3 = 267
# 89 * 4 = 356
# 89 * 5 = 445
# 89 * 6 = 534
# 89 * 7 = 623
# 89 * 8 = 712
# 89 * 9 = 801
# 89 * 10 = 890
