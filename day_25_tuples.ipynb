# %%
#tuples

# %%
t1=()

# %%
t2=(1,2,3,4,5)
print(t2)
# Out:
# (1, 2, 3, 4, 5)

# %%
t3=("Hello",3,True,5+4j,5.6)
print(t3)
# Out:
# ('Hello', 3, True, (5+4j), 5.6)

# %%
#2d tuples
t4=(1,2,(3,4))
print(t4)
# Out:
# (1, 2, (3, 4))

# %%
t5=(1)
type(t5)
# to create a single element tuple you should do this
t5=(1,)
type(t5)
# Out:
# tuple

# %%
t6=tuple("Goa")
print(t6)
# Out:
# ('G', 'o', 'a')

# %%
t7=tuple([1,2,3,5])
print(t7)
# Out:
# (1, 2, 3, 5)

# %%
#aacess

# %%
t7[0]
# Out:
# 1

# %%
t7[-1]
# Out:
# 5

# %%
t7[1:4]
# Out:
# (2, 3, 5)

# %%
#edit or add

# %%
#tuple are immutable

# %%
#delete

# %%
del t7

# %%
#print(t7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(t7)
#
# NameError: name 't7' is not defined

# %%
# we can not delete a single item bcs tuples are immutable

# %%
#but we can delete whole tuple

# %%
print(t1+t2+t3)
# Out:
# (1, 2, 3, 4, 5, 'Hello', 3, True, (5+4j), 5.6)

# %%
print(t3*3)
# Out:
# ('Hello', 3, True, (5+4j), 5.6, 'Hello', 3, True, (5+4j), 5.6, 'Hello', 3, True, (5+4j), 5.6)

# %%
for i in t3:
    print(i)
# Out:
# Hello
# 3
# True
# (5+4j)
# 5.6

# %%
# all the opertion are same as list

# %%
#all the functions are same as list

# %%
len(t2)
# Out:
# 5

# %%
min(t2)
# Out:
# 1

# %%
max(t2)
# Out:
# 5

# %%
sum(t2)
# Out:
# 15

# %%
#tuples are read only data types
