# %%
name="Atul"
print(name)
# Out:
# Atul

# %%
# There is no  variable declaration in python you just write varibale name
var=5;
print(var)
# Out:
# 5

# %%
#Dynamic typing - we does not not to declare data types compiler will automatically interprate data types

# %%
#Static typing - we declare data type before creating any variavle like in c++

# %%
print(name)
# Out:
# Atul

# %%
name=5
print(name)
# Out:
# 5

# %%
name=False

# %%
print(name)
# Out:
# False

# %%
#Dynamic binding- one variable can store diffirent data types at diffirent time we can store any type of data in same varible.

# %%
#static Binding - once we declare any variable with specific data type liek int a=5 then they can only store that type of data we can`t change data type in mid way.

# %%
#special syntax
a=5;b=4;c=10
print(a,b,c)
# Out:
# 5 4 10

# %%
a,b,c=5,4,10
print(a,b,c)
# Out:
# 5 4 10

# %%
a=b=c=6
print(a,b,c)
# Out:
# 6 6 6
