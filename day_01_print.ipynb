# %%
print("Hello World");
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
print(5.6)
# Out:
# 5.6

# %%
print(False)
# Out:
# False

# %%
print("India","UAE","Srilanka","Afganistan")
# Out:
# India UAE Srilanka Afganistan

# %%
print("India",5,False)
# Out:
# India 5 False

# %%
print("India","UAE","Srilanka","Afganistan",sep='/')
# Out:
# India/UAE/Srilanka/Afganistan

# %%
print("India","UAE","Srilanka","Afganistan",sep='-')
# Out:
# India-UAE-Srilanka-Afganistan

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello", end=' ')
print("World")
# Out:
# Hello World
