# %%
# arithmatic operation

# %%
s1="Hello"
s2="World"
print(s1+" "+s2)
# Out:
# Hello World

# %%
print("*"*50)
# Out:
# **************************************************

# %%
# Relational operation

# %%
s1==s2
# Out:
# False

# %%
s1!=s2
# Out:
# True

# %%
"Mumbai">"Pune"
#lexicographically
# Out:
# False

# %%
"Goa"<"Kolakata"
# Out:
# True

# %%
"Hello">"hello"
# Out:
# False

# %%
# Logical operations

# %%
# "" -> false   empty string is treated as a false
# "jashjs" ->true

# %%
"" and "Hello"
# Out:
# ''

# %%
"" or "Hello"
# Out:
# 'Hello'

# %%
"Hello" or "World"
# Out:
# 'Hello'

# %%
"Hello" and "World"
# Out:
# 'World'

# %%
not "Hello"
# Out:
# False

# %%
not ""
# Out:
# True

# %%
# Loop

# %%
c="Hello World"
for i in c:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
"h" in c
# Out:
# False

# %%
"H" in c
# Out:
# True

# %%
"World" in c
# Out:
# True
