# %%
# creating a string
s='Hello'
print(s)
# Out:
# Hello

# %%
s="Hello"
print(s)
# Out:
# Hello

# %%
s="""It's raining."""
print(s)
# Out:
# It's raining.

# %%
c=str("Hello")
print(c)
# Out:
# Hello
